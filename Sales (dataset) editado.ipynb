# %% [markdown]
# ### Editando dataset Sales

# %%
# Importando bibliotecas

import pandas as pd
import numpy as np

# %%
# importando tabela

base_vendas = pd.read_csv("online_sales_dataset.csv")
base_vendas
# Out:
#        InvoiceNo StockCode   Description  Quantity       InvoiceDate  \
# 0         221958  SKU_1964     White Mug        38  2020-01-01 00:00
# 1         771155  SKU_1241     White Mug        18  2020-01-01 01:00
# 2         231932  SKU_1501    Headphones        49  2020-01-01 02:00
# 3         465838  SKU_1760     Desk Lamp        14  2020-01-01 03:00
# 4         359178  SKU_1386     USB Cable       -30  2020-01-01 04:00
# ...          ...       ...           ...       ...               ...
# 49777     354083  SKU_1562      Blue Pen        25  2025-09-05 01:00
# 49778     296698  SKU_1930     USB Cable         7  2025-09-05 02:00
# 49779     177622  SKU_1766  Office Chair        43  2025-09-05 03:00
# 49780     701213  SKU_1602      Notebook        48  2025-09-05 04:00
# 49781     772215  SKU_1832     White Mug        30  2025-09-05 05:00
#
#        UnitPrice  CustomerID         Country  Discount  PaymentMethod  \
# ...

# %%
# excluindo valores negativos da coluna "Quantity"

base_vendas = base_vendas[base_vendas['Quantity'] >= 0]
#base_vendas = base_vendas[base_vendas['InvoiceDate'] <= 2024-31-10]
base_vendas
# Out:
#        InvoiceNo StockCode   Description  Quantity       InvoiceDate  \
# 0         221958  SKU_1964     White Mug        38  2020-01-01 00:00
# 1         771155  SKU_1241     White Mug        18  2020-01-01 01:00
# 2         231932  SKU_1501    Headphones        49  2020-01-01 02:00
# 3         465838  SKU_1760     Desk Lamp        14  2020-01-01 03:00
# 5         744167  SKU_1006  Office Chair        47  2020-01-01 05:00
# ...          ...       ...           ...       ...               ...
# 49777     354083  SKU_1562      Blue Pen        25  2025-09-05 01:00
# 49778     296698  SKU_1930     USB Cable         7  2025-09-05 02:00
# 49779     177622  SKU_1766  Office Chair        43  2025-09-05 03:00
# 49780     701213  SKU_1602      Notebook        48  2025-09-05 04:00
# 49781     772215  SKU_1832     White Mug        30  2025-09-05 05:00
#
#        UnitPrice  CustomerID         Country  Discount  PaymentMethod  \
# ...

# %%
# Supondo que 'InvoiceDate' esteja no formato datetime
base_vendas['InvoiceDate'] = pd.to_datetime(base_vendas['InvoiceDate'])
# Out:
# <ipython-input-4-90ebcaa641f7>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base_vendas['InvoiceDate'] = pd.to_datetime(base_vendas['InvoiceDate'])

# %%
# Filtrar as datas até 31/10/2024
base_vendas = base_vendas[base_vendas['InvoiceDate'] <= '2024-10-31']

base_vendas
# Out:
#        InvoiceNo StockCode   Description  Quantity         InvoiceDate  \
# 0         221958  SKU_1964     White Mug        38 2020-01-01 00:00:00
# 1         771155  SKU_1241     White Mug        18 2020-01-01 01:00:00
# 2         231932  SKU_1501    Headphones        49 2020-01-01 02:00:00
# 3         465838  SKU_1760     Desk Lamp        14 2020-01-01 03:00:00
# 5         744167  SKU_1006  Office Chair        47 2020-01-01 05:00:00
# ...          ...       ...           ...       ...                 ...
# 42356     107420  SKU_1885      Blue Pen        25 2024-10-30 20:00:00
# 42357     793881  SKU_1003    Headphones        49 2024-10-30 21:00:00
# 42358     355023  SKU_1563      Backpack        10 2024-10-30 22:00:00
# 42359     869208  SKU_1366  Office Chair        36 2024-10-30 23:00:00
# 42360     909450  SKU_1006       T-shirt        15 2024-10-31 00:00:00
#
#        UnitPrice  CustomerID         Country  Discount  PaymentMethod  \
# ...

# %%
base_vendas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 40290 entries, 0 to 42360
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   InvoiceNo          40290 non-null  int64
#  1   StockCode          40290 non-null  object
#  2   Description        40290 non-null  object
#  3   Quantity           40290 non-null  int64
#  4   InvoiceDate        40290 non-null  datetime64[ns]
#  5   UnitPrice          40290 non-null  float64
#  6   CustomerID         38163 non-null  float64
#  7   Country            40290 non-null  object
#  8   Discount           40290 non-null  float64
#  9   PaymentMethod      40290 non-null  object
#  10  ShippingCost       40290 non-null  float64
#  11  Category           40290 non-null  object
#  12  SalesChannel       40290 non-null  object
#  13  ReturnStatus       40290 non-null  object
#  14  ShipmentProvider   40290 non-null  object
# ...

# %%
print(base_vendas.shape)
# Out:
# (40290, 17)

# %%
print(base_vendas.isnull().sum())
# Out:
# InvoiceNo               0
# StockCode               0
# Description             0
# Quantity                0
# InvoiceDate             0
# UnitPrice               0
# CustomerID           2127
# Country                 0
# Discount                0
# PaymentMethod           0
# ShippingCost            0
# Category                0
# SalesChannel            0
# ReturnStatus            0
# ShipmentProvider        0
# WarehouseLocation     866
# OrderPriority           0
# dtype: int64

# %%
# Excluindo linhas vazias

base_vendas = base_vendas.dropna()

print(base_vendas.shape)
print(base_vendas.isnull().sum())
# Out:
# (38163, 17)
# InvoiceNo            0
# StockCode            0
# Description          0
# Quantity             0
# InvoiceDate          0
# UnitPrice            0
# CustomerID           0
# Country              0
# Discount             0
# PaymentMethod        0
# ShippingCost         0
# Category             0
# SalesChannel         0
# ReturnStatus         0
# ShipmentProvider     0
# WarehouseLocation    0
# OrderPriority        0
# dtype: int64

# %%
base_vendas
# Out:
#        InvoiceNo StockCode   Description  Quantity         InvoiceDate  \
# 0         221958  SKU_1964     White Mug        38 2020-01-01 00:00:00
# 1         771155  SKU_1241     White Mug        18 2020-01-01 01:00:00
# 2         231932  SKU_1501    Headphones        49 2020-01-01 02:00:00
# 3         465838  SKU_1760     Desk Lamp        14 2020-01-01 03:00:00
# 5         744167  SKU_1006  Office Chair        47 2020-01-01 05:00:00
# ...          ...       ...           ...       ...                 ...
# 42356     107420  SKU_1885      Blue Pen        25 2024-10-30 20:00:00
# 42357     793881  SKU_1003    Headphones        49 2024-10-30 21:00:00
# 42358     355023  SKU_1563      Backpack        10 2024-10-30 22:00:00
# 42359     869208  SKU_1366  Office Chair        36 2024-10-30 23:00:00
# 42360     909450  SKU_1006       T-shirt        15 2024-10-31 00:00:00
#
#        UnitPrice  CustomerID         Country  Discount  PaymentMethod  \
# ...

# %% [markdown]
# #### Analisando produtos e categorias
#
# * Análise dos produtos e categorias para verificar se os produtos estão classificados corretamente.

# %%
# Selecionando as categorias 'Description' e 'Category'

prod_cat = base_vendas[['Description', 'Category']]
prod_cat.head(20)
# Out:
#        Description     Category
# 0        White Mug      Apparel
# 1        White Mug  Electronics
# 2       Headphones  Electronics
# 3        Desk Lamp  Accessories
# 5     Office Chair  Electronics
# 6        USB Cable   Stationery
# 7         Notebook  Electronics
# 8   Wireless Mouse      Apparel
# 9       Headphones      Apparel
# 10        Notebook   Stationery
# 11    Office Chair    Furniture
# 12        Blue Pen  Electronics
# 13      Headphones   Stationery
# 14      Wall Clock  Electronics
# 15         T-shirt    Furniture
# 16    Office Chair      Apparel
# 17      Headphones   Stationery
# 18        Backpack  Accessories
# 19       USB Cable    Furniture
# 20      Wall Clock  Accessories

# %% [markdown]
# ###  Os produtos devem ser classificados da seguinte maneira:
#
# Furniture: Office Chair, Desk Lamp
#
# Stationery: Blue Pen, Notebook
#
# Accessories: Backpack, White Mug, Wall Clock, Desk Lamp
#
# Apparel: T-shirt
#
# Electronics: Wireless Mouse, USB Cable, Headphones
#
# * Conforme a tabela acima, percebe-se que há produtos classificados erroneamente, como exemplo, 'White Mug' (canceca branca) classificado como 'Apparel' (vestuário) e também classificado como "Eletronics".

# %%
# Dicionário com os produtos categorizados corretamente

Category = {
    'T-shirt': 'Apparel',
    'Notebook': 'Stationery',
    'Wireless Mouse': 'Electronics',
    'USB Cable': 'Accessories',
    'Backpack': 'Accessories',
    'Wall Clock': 'Accessories',
    'Blue Pen': 'Stationery',
    'Office Chair': 'Furniture',
    'Desk Lamp': 'Accessories',
    'White Mug': 'Accessories',
    'Headphones': 'Electronics'
}

# %%
# Aplicar a correção no DataFrame

base_vendas['Category'] = base_vendas['Description'].map(Category)
base_vendas
# Out:
# <ipython-input-13-b90350bcd807>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base_vendas['Category'] = base_vendas['Description'].map(Category)
#        InvoiceNo StockCode   Description  Quantity         InvoiceDate  \
# 0         221958  SKU_1964     White Mug        38 2020-01-01 00:00:00
# 1         771155  SKU_1241     White Mug        18 2020-01-01 01:00:00
# 2         231932  SKU_1501    Headphones        49 2020-01-01 02:00:00
# 3         465838  SKU_1760     Desk Lamp        14 2020-01-01 03:00:00
# 5         744167  SKU_1006  Office Chair        47 2020-01-01 05:00:00
# ...          ...       ...           ...       ...                 ...
# 42356     107420  SKU_1885      Blue Pen        25 2024-10-30 20:00:00
# ...

# %%
base_vendas.groupby(["Category","Description"]).size()
base_vendas
# Out:
#        InvoiceNo StockCode   Description  Quantity         InvoiceDate  \
# 0         221958  SKU_1964     White Mug        38 2020-01-01 00:00:00
# 1         771155  SKU_1241     White Mug        18 2020-01-01 01:00:00
# 2         231932  SKU_1501    Headphones        49 2020-01-01 02:00:00
# 3         465838  SKU_1760     Desk Lamp        14 2020-01-01 03:00:00
# 5         744167  SKU_1006  Office Chair        47 2020-01-01 05:00:00
# ...          ...       ...           ...       ...                 ...
# 42356     107420  SKU_1885      Blue Pen        25 2024-10-30 20:00:00
# 42357     793881  SKU_1003    Headphones        49 2024-10-30 21:00:00
# 42358     355023  SKU_1563      Backpack        10 2024-10-30 22:00:00
# 42359     869208  SKU_1366  Office Chair        36 2024-10-30 23:00:00
# 42360     909450  SKU_1006       T-shirt        15 2024-10-31 00:00:00
#
#        UnitPrice  CustomerID         Country  Discount  PaymentMethod  \
# ...

# %%
# Salvar o DataFrame em um arquivo CSV
base_vendas.to_csv('Sales_novo.csv', index=False)
